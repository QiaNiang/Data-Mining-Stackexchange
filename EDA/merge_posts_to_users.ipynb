# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import re
import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime

# %%
folder = r"D:\Studium\DM-Dataset\literature.stackexchange.com\Literature_CSV_raw"
file1 = "literaturePosts_with_sentiment.csv"
path1 = os.path.join(folder, file1)
df_posts = pd.read_csv(path1)

file2 = "Users.csv" 
path2 = os.path.join(folder, file2)
df_users = pd.read_csv(path2)

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17306 entries, 0 to 17305
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     17306 non-null  int64
#  1   PostTypeId             17306 non-null  int64
#  2   CreationDate           17306 non-null  object
#  3   Score                  17306 non-null  int64
#  4   ViewCount              17306 non-null  float64
#  5   Body                   17306 non-null  object
#  6   OwnerUserId            16647 non-null  float64
#  7   LastEditorUserId       11587 non-null  float64
#  8   LastEditDate           11939 non-null  object
#  9   LastActivityDate       17306 non-null  object
#  10  Title                  6780 non-null   object
#  11  Tags                   6780 non-null   object
#  12  AnswerCount            17306 non-null  float64
#  13  CommentCount           17306 non-null  int64
# ...

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14491 entries, 0 to 14490
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              14491 non-null  int64
#  1   Reputation      14491 non-null  int64
#  2   CreationDate    14491 non-null  object
#  3   DisplayName     14488 non-null  object
#  4   LastAccessDate  14491 non-null  object
#  5   Location        4854 non-null   object
#  6   AboutMe         4511 non-null   object
#  7   Views           14491 non-null  int64
#  8   UpVotes         14491 non-null  int64
#  9   DownVotes       14491 non-null  int64
#  10  AccountId       14488 non-null  float64
#  11  WebsiteUrl      2254 non-null   object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.3+ MB

# %%
df_posts["OwnerUserId"] = df_posts["OwnerUserId"].astype("Int64") 
df_users["Id"] = df_users["Id"].astype("Int64")

# %%
merged_df = df_posts.merge(
    df_users,
    how="right",
    left_on="OwnerUserId",
    right_on="Id",
    suffixes=('_post', '_user')
)

# %%
id_count_columns = [col for col in merged_df.columns if 'id' in col.lower() or 'count' in col.lower()]

for col in id_count_columns:
    merged_df[col] = merged_df[col].astype("Int64")

# %%
merged_df
# Out:
#        Id_post  PostTypeId        CreationDate_post  Score  ViewCount  \
# 0          147           5  2017-01-18 22:16:24.797    0.0          0
# 1          180           5  2017-01-19 00:21:41.320    0.0          0
# 2          199           5  2017-01-19 01:09:05.437    0.0          0
# 3          205           5  2017-01-19 01:29:31.973    0.0          0
# 4          271           5  2017-01-19 15:05:18.390    0.0          0
# ...        ...         ...                      ...    ...        ...
# 27721    26549           1  2024-03-31 00:36:45.513    8.0        487
# 27722     <NA>        <NA>                      NaN    NaN       <NA>
# 27723     <NA>        <NA>                      NaN    NaN       <NA>
# 27724     <NA>        <NA>                      NaN    NaN       <NA>
# 27725     <NA>        <NA>                      NaN    NaN       <NA>
#
#                                                     Body  OwnerUserId  \
# ...

# %%
filename = "posts_to_users.csv"
output_path = f"{folder}\\{filename}"

merged_df.to_csv(output_path, index=False, encoding='utf-8-sig')
